# %% [markdown]
# <a href="https://colab.research.google.com/github/mairalira/VC_Maira/blob/master/AA2_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch pandas numpy torchvision opencv-python
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
# !git clone https://github.com/mairalira/VC_Maira.git
# %cd VC_Maira
# Out:
# Cloning into 'VC_Maira'...
# remote: Enumerating objects: 1239, done.
# remote: Counting objects: 100% (605/605), done.
# remote: Compressing objects: 100% (167/167), done.
# remote: Total 1239 (delta 441), reused 595 (delta 438), pack-reused 634
# Receiving objects: 100% (1239/1239), 369.93 KiB | 28.46 MiB/s, done.
# Resolving deltas: 100% (874/874), done.
# /content/VC_Maira

# %%
import os

checkpoint_dir = "./checkpoint"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

results_dir = "./results"
if not os.path.exists(results_dir):
    os.makedirs(results_dir)

#data_dir = "./data"
#if not os.path.exists(data_dir):
#    os.makedirs(data_dir)

# %%
# Run the main script to test the resnet50 with cifar10 data without pruning
# !python main.py --arch resnet50 --data-type cifar10 --save-dir results --train True --epochs 10
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Train Epoch: [34496/50000 (69%)]	Loss: 1.219494
# Train Epoch: [34560/50000 (69%)]	Loss: 0.999172
# Train Epoch: [34624/50000 (69%)]	Loss: 0.899354
# Train Epoch: [34688/50000 (69%)]	Loss: 0.705606
# Train Epoch: [34752/50000 (69%)]	Loss: 1.151717
# Train Epoch: [34816/50000 (70%)]	Loss: 1.229754
# Train Epoch: [34880/50000 (70%)]	Loss: 0.977865
# Train Epoch: [34944/50000 (70%)]	Loss: 0.928467
# Train Epoch: [35008/50000 (70%)]	Loss: 0.939377
# Train Epoch: [35072/50000 (70%)]	Loss: 0.998432
# Train Epoch: [35136/50000 (70%)]	Loss: 0.898250
# Train Epoch: [35200/50000 (70%)]	Loss: 0.630902
# Train Epoch: [35264/50000 (70%)]	Loss: 0.912560
# Train Epoch: [35328/50000 (71%)]	Loss: 0.865514
# Train Epoch: [35392/50000 (71%)]	Loss: 0.821594
# Train Epoch: [35456/50000 (71%)]	Loss: 0.937373
# Train Epoch: [35520/50000 (71%)]	Loss: 1.173523
# Train Epoch: [35584/50000 (71%)]	Loss: 0.832288
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/

# !zip -r heatmap_no_pruning_final.zip /content/VC_Maira/gradcam_results

from google.colab import files
files.download('heatmap_no_pruning_final.zip')
# Out:
# /content/drive/MyDrive
#   adding: content/VC_Maira/gradcam_results/ (stored 0%)
#   adding: content/VC_Maira/gradcam_results/original_batch88_image0.png (deflated 10%)
#   adding: content/VC_Maira/gradcam_results/gradcam_batch42_image0.png (deflated 5%)
#   adding: content/VC_Maira/gradcam_results/heatmap_batch0_image0.png (deflated 40%)
#   adding: content/VC_Maira/gradcam_results/gradcam_batch7_image0.png (deflated 3%)
#   adding: content/VC_Maira/gradcam_results/heatmap_batch56_image0.png (deflated 38%)
#   adding: content/VC_Maira/gradcam_results/original_batch156_image0.png (deflated 9%)
#   adding: content/VC_Maira/gradcam_results/gradcam_batch132_image0.png (deflated 13%)
#   adding: content/VC_Maira/gradcam_results/gradcam_batch130_image0.png (deflated 5%)
#   adding: content/VC_Maira/gradcam_results/original_batch67_image0.png (deflated 11%)
#   adding: content/VC_Maira/gradcam_results/original_batch31_image0.png (deflated 11%)
# ...

# %%
# Run the main script to test the resnet50 with cifar10 data
# !python main.py --arch resnet50 --data-type cifar10 --save-dir results --prune --epochs 10
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Train Epoch: [34368/50000 (69%)]	Loss: 0.219354
# Train Epoch: [34432/50000 (69%)]	Loss: 0.266824
# Train Epoch: [34496/50000 (69%)]	Loss: 0.248405
# Train Epoch: [34560/50000 (69%)]	Loss: 0.502800
# Train Epoch: [34624/50000 (69%)]	Loss: 0.159521
# Train Epoch: [34688/50000 (69%)]	Loss: 0.182202
# Train Epoch: [34752/50000 (69%)]	Loss: 0.337976
# Train Epoch: [34816/50000 (70%)]	Loss: 0.235419
# Train Epoch: [34880/50000 (70%)]	Loss: 0.272628
# Train Epoch: [34944/50000 (70%)]	Loss: 0.301161
# Train Epoch: [35008/50000 (70%)]	Loss: 0.332109
# Train Epoch: [35072/50000 (70%)]	Loss: 0.240500
# Train Epoch: [35136/50000 (70%)]	Loss: 0.126973
# Train Epoch: [35200/50000 (70%)]	Loss: 0.149820
# Train Epoch: [35264/50000 (70%)]	Loss: 0.105178
# Train Epoch: [35328/50000 (71%)]	Loss: 0.202165
# Train Epoch: [35392/50000 (71%)]	Loss: 0.221164
# Train Epoch: [35456/50000 (71%)]	Loss: 0.278379
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/

# !zip -r heatmap_pruning_10.zip /content/VC_Maira/gradcam_results

from google.colab import files
files.download('heatmap_pruning_10.zip')
# Out:
# /content/drive/MyDrive
#   adding: content/VC_Maira/gradcam_results/ (stored 0%)
#   adding: content/VC_Maira/gradcam_results/heatmap_batch101_image0.png (deflated 43%)
#   adding: content/VC_Maira/gradcam_results/gradcam_batch62_image0.png (deflated 5%)
#   adding: content/VC_Maira/gradcam_results/heatmap_batch90_image0.png (deflated 43%)
#   adding: content/VC_Maira/gradcam_results/original_batch38_image0.png (deflated 6%)
#   adding: content/VC_Maira/gradcam_results/original_batch77_image0.png (deflated 11%)
#   adding: content/VC_Maira/gradcam_results/original_batch151_image0.png (deflated 8%)
#   adding: content/VC_Maira/gradcam_results/heatmap_batch7_image0.png (deflated 44%)
#   adding: content/VC_Maira/gradcam_results/heatmap_batch31_image0.png (deflated 42%)
#   adding: content/VC_Maira/gradcam_results/original_batch40_image0.png (deflated 10%)
#   adding: content/VC_Maira/gradcam_results/gradcam_batch96_image0.png (deflated 6%)
# ...
